# %% [markdown]
# <a href="https://colab.research.google.com/github/ngrshx/panda_tasks_collab/blob/main/Pandas_codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/coffee.csv')
df.head(5)
# Out:
#          Day Coffee Type  Units Sold
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
df.tail(8)
# Out:
#          Day Coffee Type  Units Sold
# 6   Thursday    Espresso          40
# 7   Thursday       Latte          30
# 8     Friday    Espresso          45
# 9     Friday       Latte          35
# 10  Saturday    Espresso          45
# 11  Saturday       Latte          35
# 12    Sunday    Espresso          45
# 13    Sunday       Latte          35

# %%
df.describe(include=[int])
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
df.describe(exclude=[int])
# Out:
#            Day Coffee Type
# count       14          14
# unique       7           2
# top     Monday    Espresso
# freq         2           7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
df.columns

df['Price'] = 12

# %%
df.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold', 'price', 'Price'], dtype='object')

# %%
df.drop('price', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Day', 'Coffee Type', 'Units Sold', 'Price'], dtype='object')

# %%
df.head(3)
# Out:
#        Day Coffee Type  Units Sold  Price
# 0   Monday    Espresso          25     12
# 1   Monday       Latte          15     12
# 2  Tuesday    Espresso          30     12

# %%
df['Price'] = [5, 6]*7

# %%
df.head(7)
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25      5
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      5
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      5
# 5  Wednesday       Latte          25      6
# 6   Thursday    Espresso          40      5

# %%
df.isnull().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     0
# Price          0
# dtype: int64

# %%
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25      5
# 1     Monday       Latte          15      6
# 2    Tuesday    Espresso          30      5
# 3    Tuesday       Latte          20      6
# 4  Wednesday    Espresso          35      5
# 5  Wednesday       Latte          25      6
# 6   Thursday    Espresso          40      5
# 7   Thursday       Latte          30      6
# 8     Friday    Espresso          45      5
# 9     Friday       Latte          35      6

# %%
import pandas as pn

df = pn.read_csv('/train.csv')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.loc[1:6, ['Name', 'Age']]
# Out:
#                                                 Name   Age
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 6                            McCarthy, Mr. Timothy J  54.0

# %%
df.tail(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# Index([  1,   3,   6,  10,  11,  21,  23,  27,  52,  54,
#        ...
#        835, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=183)

# %%
df.iloc[1:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
# 21           22         1       2
# 23           24         1       1
# 27           28         0       1
# 52           53         1       1
# 54           55         0       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                        McCarthy, Mr. Timothy J    male  54.0      0      0
# 10               Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11                      Bonnell, Miss. Elizabeth  female  58.0      0      0
# 21                         Beesley, Mr. Lawrence    male  34.0      0      0
# 23                  Sloper, Mr. William Thompson    male  28.0      0      0
# 27                Fortune, Mr. Charles Alexander    male  19.0      3      2
# ...

# %%
df[df.Age>10.0][['Name', "Age"]].sort_values(by ='Age', ascending=False)
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0
# 96              Goldschmidt, Mr. George B  71.0
# 745          Crosby, Capt. Edward Gifford  70.0
# 54         Ostby, Mr. Engelhart Cornelius  65.0
# 456             Millet, Mr. Francis Davis  65.0
# ..                                    ...   ...
# 853             Lines, Miss. Mary Conover  16.0
# 504                 Maioni, Miss. Roberta  16.0
# 689     Madill, Miss. Georgette Alexandra  15.0
# 435             Carter, Miss. Lucile Polk  14.0
# 802   Carter, Master. William Thornton II  11.0
#
# [173 rows x 2 columns]

# %%
df.apply(lambda x:"less" if x.Age < 50 and x.Age > 10 else 'high', axis=1 )
# Out:
# 1      less
# 3      less
# 6      high
# 10     high
# 11     high
#        ...
# 871    less
# 872    less
# 879    high
# 887    less
# 889    less
# Length: 183, dtype: object

# %%
df[df['Age'].between(10, 50)][['Name', 'Age']].sort_values(by='Age', ascending=False)
# Out:
#                                                 Name   Age
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  50.0
# 177                       Isham, Miss. Ann Elizabeth  50.0
# 544                       Douglas, Mr. Walter Donald  50.0
# 434                        Silvey, Mr. William Baird  50.0
# 453                         Goldenberg, Mr. Samuel L  49.0
# ..                                               ...   ...
# 329                     Hippach, Miss. Jean Gertrude  16.0
# 853                        Lines, Miss. Mary Conover  16.0
# 689                Madill, Miss. Georgette Alexandra  15.0
# 435                        Carter, Miss. Lucile Polk  14.0
# 802              Carter, Master. William Thornton II  11.0
#
# [141 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.rename(columns={'Name': 'name', 'Age': 'age','Ticket': 'bilet', "PassengerId":"Mushteri_Nomresi"}, inplace=True)

# %%
df.columns
# Out:
# Index(['Mushteri_Nomresi', 'Survived', 'Pclass', 'name', 'Sex', 'age', 'SibSp',
#        'Parch', 'bilet', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Mushteri_Nomresi    Survived      Pclass         age       SibSp  \
# count        183.000000  183.000000  183.000000  183.000000  183.000000
# mean         455.366120    0.672131    1.191257   35.674426    0.464481
# std          247.052476    0.470725    0.515187   15.643866    0.644159
# min            2.000000    0.000000    1.000000    0.920000    0.000000
# 25%          263.500000    0.000000    1.000000   24.000000    0.000000
# 50%          457.000000    1.000000    1.000000   36.000000    0.000000
# 75%          676.000000    1.000000    1.000000   47.500000    1.000000
# max          890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df['age'].mean()
# Out:
# 35.6744262295082

# %%
df['age'].min()
# Out:
# 0.92

# %%
df["age"].median()
# Out:
# 36.0

# %%
df["age"].mode()
# Out:
# 0    36.0
# Name: age, dtype: float64
